# %% [markdown]
# # Results and Analyses
#
# Present the results you contributed to the project using figures and/or tables. Explain what these results mean in the context of the project and how they advance its overall goals.
# Ensure all figures are clearly labeled, legible, and convey a clear message.
#
# The notebook must run successfully in the provided environment and load all relevant models and datasets correctly.
#
# Clearly demonstrate your individual technical contribution. Go beyond reporting final metrics by including meaningful explorations such as qualitative examples, baseline comparisons, visualizations, error analyses, ablation studies, performance breakdowns, attention or embedding analyses, prompting experiments, dataset investigations, or other insightful analyses.
#
# Show evidence of critical thinking and interpretation of results, not just raw outputs.

# %% [markdown]
# # Other contributions
#
# Here you can describe other contributions like the implementation of a specific algorithm, the design of an experiment, or the development of a tool that was used in the project.
# Please do NOT copy paste the code here, refer to the `.py` script containing the code instead.
